# %%
import pandas as pd

# %%
train = pd.read_csv(test.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_g/28v8q_cn747f6t0lktyj44500000gn/T/ipykernel_67146/1319254863.py in <module>
# ----> 1 train = pd.read_csv(test.csv)
#
# NameError: name 'test' is not defined
